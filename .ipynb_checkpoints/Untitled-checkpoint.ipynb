# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse
import cv2
import time
import uvicorn
import nest_asyncio
from win32api import GetSystemMetrics
import numpy as np
from PIL import ImageGrab
import datetime
import pyautogui
nest_asyncio.apply()
app = FastAPI()
.time()

def generate_frames():
    c = 0
    # Variable for frame interval (in seconds) to achieve desired FPS
    frame_interval = 1 / 5

    while True:
        # Record start time of processing a frame
        frame_start_time = time.time()
        img = ImageGrab.grab()  # Capture the screen
        img = np.array(img)
        img_final = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        if True:
                # Resize the frame to 480p resolution
                # img_final = cv2.resize(img_final, (854, 480))  # 480p resolution is 854x480
                img_final = cv2.resize(img_final, (640, 360))  # 480p resolution is 854x480
                # Convert the frame to JPEG format for streaming
                _, buffer = cv2.imencode('.jpg', img_final)
                c+=1
                
                yield (b'--frame\r\n'
                       b'Content-Type: image/jpeg\r\n\r\n' + buffer.tobytes() + b'\r\n')
        # Calculate elapsed time
        elapsed_time = time.time() - start_time
    
        # If one second has elapsed, calculate and print FPS
        if elapsed_time >= 1:
            fps = num_frames / elapsed_time
            print("FPS:", fps)
            num_frames = 0
            start_time = time.time()
        frame_time = time.time() - frame_start_time
        # Calculate the delay required to achieve desired FPS
        delay = frame_interval - frame_time
        print(f"delay {delay}")
    
        # Introduce the delay
        time.sleep(delay)
        if c>=5:
            break
    
            
@app.get("/video_feed")
async def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")

if __name__ == "__main__":
    uvicorn.run(app, host="localhost", port=8000)
# Out:
# INFO:     Started server process [6616]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8000 (Press CTRL+C to quit)
# INFO:     ::1:50859 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50869 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50890 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50893 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50894 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50897 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50900 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50975 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50977 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50978 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50979 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50982 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50983 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [6616]

# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse
import cv2
import time
import uvicorn
import nest_asyncio
from win32api import GetSystemMetrics
import numpy as np
from PIL import ImageGrab
import datetime
import pyautogui
nest_asyncio.apply()
app = FastAPI()

def generate_frames():
    c = 0
    # Variable for frame interval (in seconds) to achieve desired FPS
    frame_interval = 1 / 4
    start_time = time.time()
    num_frames = 0
    while True:
        print(f'total {c}')
        # Record start time of processing a frame
        frame_start_time = time.time()
        img = ImageGrab.grab()  # Capture the screen
        img = np.array(img)
        # img_final = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_final = img

        if True:
                # Resize the frame to 480p resolution
                # img_final = cv2.resize(img_final, (854, 480))  # 480p resolution is 854x480
                # img_final = cv2.resize(img_final, (640, 360))  # 480p resolution is 854x480
                img_final = cv2.resize(img_final, (1280, 720))  # 480p resolution is 854x480
                # Convert the frame to JPEG format for streaming
                _, buffer = cv2.imencode('.jpg', img_final)
                c+=1
                num_frames+=1
                
                yield (b'--frame\r\n'
                       b'Content-Type: image/jpeg\r\n\r\n' + buffer.tobytes() + b'\r\n')
        # Calculate elapsed time
        elapsed_time = time.time() - start_time
    
        # If one second has elapsed, calculate and print FPS
        if elapsed_time >= 1:
            fps = num_frames / elapsed_time
            print("FPS:", fps)
            
        frame_time = time.time() - frame_start_time
        # Calculate the delay required to achieve desired FPS
        delay = frame_interval - frame_time
        e = time.time()
        l = e-start_time
        print(f"total time {l}")
        print(f"delay {delay}")


        try:
            # Introduce the delay
            time.sleep(delay)
        except:
            # time.sleep(0.15)
            pass

    
            
@app.get("/video_feed")
async def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")

if __name__ == "__main__":
    uvicorn.run(app, host="localhost", port=3000)
# Out:
# INFO:     Started server process [1404]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:3000 (Press CTRL+C to quit)
# INFO:     35.202.214.171:0 - "GET /video_feed HTTP/1.1" 200 OK
# total 0
# total time 0.10806798934936523
# delay 0.15045833587646484
# total 1
# total time 0.34680938720703125
# delay 0.17804336547851562
# total 2
# total time 0.6116604804992676
# delay 0.1777806282043457
# total 3
# total time 0.8843576908111572
# delay 0.16888093948364258
# total 4
# FPS: 4.357196936013477
# total time 1.147526741027832
# delay 0.16954803466796875
# total 5
# FPS: 4.251429034797563
# total time 1.411290168762207
# delay 0.170576810836792
# total 6
# FPS: 4.172318859836419
# total time 1.6777241230010986
# delay 0.16824936866760254
# total 7
# FPS: 4.15211487972151
# total time 1.9267289638519287
# delay 0.18212080001831055
# total 8
# FPS: 3.999587207588599
# total time 2.250232219696045
# delay 0.12186598777770996
# total 9
# FPS: 4.039052904002408
# total time 2.475827932357788
# delay 0.15644407272338867
# total 10
# FPS: 3.9031961775239266
# total time 2.8182032108306885
# delay 0.09460997581481934
# total 11
# FPS: 3.9845597625207305
# total time 3.011625051498413
# delay 0.16073346138000488
# total 12
# FPS: 3.9660097982916453
# total time 3.2778537273406982
# delay 0.15767550468444824
# total 13
# FPS: 3.9402657775518963
# total time 3.5530598163604736
# delay 0.15214252471923828
# total 14
# FPS: 3.934787208234098
# total time 3.812150239944458
# delay 0.15057778358459473
# total 15
# FPS: 3.933317332531535
# total time 4.0683207511901855
# delay 0.14616799354553223
# total 16
# FPS: 3.9116405690092457
# total time 4.346002578735352
# delay 0.13251829147338867
# total 17
# FPS: 3.883426836180409
# total time 4.63508152961731
# delay 0.10684037208557129
# total 18
