# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse
import cv2
import time
import uvicorn
import nest_asyncio
from win32api import GetSystemMetrics
import numpy as np
from PIL import ImageGrab
import datetime
import pyautogui
nest_asyncio.apply()
app = FastAPI()
.time()

def generate_frames():
    c = 0
    # Variable for frame interval (in seconds) to achieve desired FPS
    frame_interval = 1 / 5

    while True:
        # Record start time of processing a frame
        frame_start_time = time.time()
        img = ImageGrab.grab()  # Capture the screen
        img = np.array(img)
        img_final = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        if True:
                # Resize the frame to 480p resolution
                # img_final = cv2.resize(img_final, (854, 480))  # 480p resolution is 854x480
                img_final = cv2.resize(img_final, (640, 360))  # 480p resolution is 854x480
                # Convert the frame to JPEG format for streaming
                _, buffer = cv2.imencode('.jpg', img_final)
                c+=1
                
                yield (b'--frame\r\n'
                       b'Content-Type: image/jpeg\r\n\r\n' + buffer.tobytes() + b'\r\n')
        # Calculate elapsed time
        elapsed_time = time.time() - start_time
    
        # If one second has elapsed, calculate and print FPS
        if elapsed_time >= 1:
            fps = num_frames / elapsed_time
            print("FPS:", fps)
            num_frames = 0
            start_time = time.time()
        frame_time = time.time() - frame_start_time
        # Calculate the delay required to achieve desired FPS
        delay = frame_interval - frame_time
        print(f"delay {delay}")
    
        # Introduce the delay
        time.sleep(delay)
        if c>=5:
            break
    
            
@app.get("/video_feed")
async def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")

if __name__ == "__main__":
    uvicorn.run(app, host="localhost", port=8000)
# Out:
# INFO:     Started server process [6616]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8000 (Press CTRL+C to quit)
# INFO:     ::1:50859 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50869 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50890 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50893 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50894 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50897 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50900 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50975 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50977 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50978 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50979 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50982 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     ::1:50983 - "GET /video_feed HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [6616]

# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse
import cv2
import time
import uvicorn
import nest_asyncio
from win32api import GetSystemMetrics
import numpy as np
from PIL import ImageGrab
import datetime
import pyautogui
nest_asyncio.apply()
app = FastAPI()

def generate_frames():
    c = 0
    # Variable for frame interval (in seconds) to achieve desired FPS
    frame_interval = 1 / 4
    start_time = time.time()
    num_frames = 0
    while True:
        print(f'total {c}')
        # Record start time of processing a frame
        frame_start_time = time.time()
        img = ImageGrab.grab()  # Capture the screen
        img = np.array(img)
        # img_final = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_final = img

        if True:
                # Resize the frame to 480p resolution
                # img_final = cv2.resize(img_final, (854, 480))  # 480p resolution is 854x480
                # img_final = cv2.resize(img_final, (640, 360))  # 480p resolution is 854x480
                img_final = cv2.resize(img_final, (1280, 720))  # 480p resolution is 854x480
                # Convert the frame to JPEG format for streaming
                _, buffer = cv2.imencode('.jpg', img_final)
                c+=1
                num_frames+=1
                
                yield (b'--frame\r\n'
                       b'Content-Type: image/jpeg\r\n\r\n' + buffer.tobytes() + b'\r\n')
        # Calculate elapsed time
        elapsed_time = time.time() - start_time
    
        # If one second has elapsed, calculate and print FPS
        if elapsed_time >= 1:
            fps = num_frames / elapsed_time
            print("FPS:", fps)
            
        frame_time = time.time() - frame_start_time
        # Calculate the delay required to achieve desired FPS
        delay = frame_interval - frame_time
        e = time.time()
        l = e-start_time
        print(f"total time {l}")
        print(f"delay {delay}")


        try:
            # Introduce the delay
            time.sleep(delay)
        except:
            # time.sleep(0.15)
            pass

    
            
@app.get("/video_feed")
async def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")

if __name__ == "__main__":
    uvicorn.run(app, host="localhost", port=3000)
# Out:
# INFO:     Started server process [13760]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:3000 (Press CTRL+C to quit)
# INFO:     34.122.110.127:0 - "GET /video_feed HTTP/1.1" 200 OK
# total 0
# total time 0.11617279052734375
# delay 0.1408233642578125
# total 1
# total time 0.34482693672180176
# delay 0.16541838645935059
# total 2
# total time 0.6132659912109375
# delay 0.16258478164672852
# total 3
# total time 0.8784871101379395
# delay 0.16115117073059082
# total 4
# FPS: 4.452528383607306
# total time 1.122957468032837
# delay 0.1816401481628418
# total 5
# FPS: 4.277164073881957
# total time 1.4027986526489258
# delay 0.16701197624206543
# total 6
# FPS: 4.234560148520492
# total time 1.653064250946045
# delay 0.18261241912841797
# total 7
# FPS: 4.159919664027027
# total time 1.9231140613555908
# delay 0.17879486083984375
# total 8
# FPS: 4.1052390150185
# total time 2.1923205852508545
# delay 0.17542004585266113
# total 9
# FPS: 4.049264996786117
# total time 2.4695839881896973
# delay 0.16446566581726074
# total 10
# FPS: 4.004813691661244
# total time 2.746694564819336
# delay 0.15309953689575195
# total 11
# FPS: 4.028499359086978
# total time 2.97979474067688
# delay 0.17481279373168945
# total 12
# FPS: 3.994621183555005
# total time 3.254376173019409
# delay 0.16579413414001465
# total 13
# FPS: 4.012388605795334
# total time 3.4891934394836426
# delay 0.1823875904083252
# total 14
# FPS: 3.9873226147132503
# total time 3.762913942337036
# delay 0.17294621467590332
# total 15
# FPS: 3.979867731651675
# total time 4.020234107971191
# delay 0.18035173416137695
# total 16
# FPS: 3.9355738209092106
# total time 4.320573568344116
# delay 0.1460566520690918
# total 17
# FPS: 3.9536302715569875
# total time 4.5527777671813965
# delay 0.17864012718200684
# total 18
# FPS: 3.930363539428278
# total time 4.834158420562744
# delay 0.16382384300231934
# total 19
# FPS: 3.9192500515684157
# total time 5.103017091751099
# delay 0.15952396392822266
# total 20
# FPS: 3.901346676282387
# total time 5.38275671005249
# delay 0.1453571319580078
# total 21
# FPS: 3.920942817524462
# total time 5.6118950843811035
# delay 0.1809983253479004
# total 22
# FPS: 3.902238578329288
# total time 5.894052743911743
# delay 0.16338562965393066
# total 23
# FPS: 3.901963224832512
# total time 6.150749921798706
# delay 0.17255640029907227
# total 24
# FPS: 3.899189477317045
# total time 6.411588907241821
# delay 0.17533302307128906
# total 25
# FPS: 3.8982242709893815
# total time 6.669703483581543
# delay 0.18145155906677246
# total 26
# FPS: 3.88811628277457
# total time 6.944236755371094
# delay 0.17238974571228027
# total 27
# FPS: 3.8824853761952913
# total time 7.2118752002716064
# delay 0.17035698890686035
# total 28
# FPS: 3.8894886629715804
# total time 7.455992937088013
# delay 0.17788195610046387
# total 29
# FPS: 3.8921919324625276
# total time 7.7077391147613525
# delay 0.17800378799438477
# total 30
# FPS: 3.895379605860999
# total time 7.958146095275879
# delay 0.18059659004211426
# total 31
# FPS: 3.8886762825584005
# total time 8.229021310806274
# delay 0.1750037670135498
# total 32
# FPS: 3.894251015216701
# total time 8.474030017852783
# delay 0.18499159812927246
# total 33
# FPS: 3.890617396360099
# total time 8.738972902297974
# delay 0.18636155128479004
# total 34
# FPS: 3.8704297555654983
# total time 9.04292345046997
# delay 0.14835667610168457
# total 35
# FPS: 3.8787970456037475
# total time 9.281228065490723
# delay 0.17510437965393066
# total 36
# FPS: 3.874043136165325
# total time 9.551054954528809
# delay 0.171356201171875
# total 37
# FPS: 3.875015283455865
# total time 9.806412935256958
# delay 0.18200469017028809
# total 38
# FPS: 3.8632773926205948
# total time 10.096043348312378
# delay 0.15887093544006348
# total 39
# FPS: 3.870019311556026
# total time 10.33586573600769
# delay 0.18404316902160645
# total 40
# FPS: 3.8587656883805255
# total time 10.62515926361084
# delay 0.15851974487304688
# total 41
# FPS: 3.866081249943214
# total time 10.86371374130249
# delay 0.1732192039489746
# total 42
# FPS: 3.8627890253014883
# total time 11.132853269577026
# delay 0.16872954368591309
# total 43
# FPS: 3.8690754123818336
# total time 11.372225999832153
# delay 0.18176746368408203
# total 44
# FPS: 3.867779679138336
# total time 11.634582042694092
# delay 0.17077136039733887
# total 45
# FPS: 3.8478853251978715
# total time 11.954618215560913
# delay 0.11651134490966797
# total 46
# FPS: 3.8184407414627373
# total time 12.30868911743164
# delay 0.01586437225341797
# total 47
# FPS: 3.6817684638108292
# total time 13.037723302841187
# delay -0.46202969551086426
# total 48
# FPS: 3.6595272068867613
# total time 13.389716625213623
# delay -0.10199332237243652
# total 49
# FPS: 3.626962298185289
# total time 13.785640954971313
# delay -0.14592432975769043
# total 50
# FPS: 3.5264407256627672
# total time 14.462259531021118
# delay -0.4266185760498047
# total 51
# FPS: 3.5057341863729237
# total time 14.833368062973022
# delay -0.1211085319519043
# total 52
# FPS: 3.4201755855823435
# total time 15.497411489486694
# delay -0.4140434265136719
# total 53
# FPS: 3.413746860792629
# total time 15.819581747055054
# delay -0.07217025756835938
# total 54
# FPS: 3.4100178699953037
# total time 16.130444765090942
# delay -0.06086301803588867
# total 55
# FPS: 3.4082107251750737
# total time 16.430908918380737
# delay -0.05046415328979492
# total 56
# FPS: 3.4084678614748096
# total time 16.723056316375732
# delay -0.041640520095825195
# total 57
# FPS: 3.407637108049
# total time 17.020591735839844
# delay -0.04701733589172363
# total 58
# FPS: 3.45257868059738
# total time 17.08867645263672
# delay 0.181915283203125
# total 59
# FPS: 3.4145480710361764
# total time 17.571871519088745
# delay -0.04118084907531738
# total 60
# FPS: 3.4070837313828894
# total time 17.904626607894897
# delay -0.08275508880615234
# total 61
# FPS: 3.3565119133932244
# total time 18.47209930419922
# delay -0.3174726963043213
# total 62
# FPS: 3.3557506080620514
# total time 18.773743152618408
# delay -0.05164384841918945
# total 63
# FPS: 3.311113515586303
# total time 19.328845024108887
# delay -0.3051018714904785
# total 64
# FPS: 3.3102524484057367
# total time 19.63664221763611
# delay -0.05779719352722168
# total 65
# FPS: 3.2679678603939712
# total time 20.197092056274414
# delay -0.31044983863830566
# total 66
# FPS: 3.270664681553402
# total time 20.485132694244385
# delay -0.0380406379699707
# total 67
# FPS: 3.2378461882281844
# total time 21.001615285873413
# delay -0.2664825916290283
# total 68
# FPS: 3.178069765141913
# total time 21.711291790008545
# delay -0.45967650413513184
# total 69
# FPS: 3.153363012622247
# total time 22.199191331863403
# delay -0.23688530921936035
# total 70
# FPS: 3.1590122248160406
# total time 22.475379943847656
# delay -0.02618861198425293
# total 71
# FPS: 3.142118099068932
# total time 22.915238857269287
# delay -0.18985891342163086
# total 72
# FPS: 3.134332254898123
# total time 23.290447235107422
# delay -0.12520837783813477
# total 73
# FPS: 3.148385524566549
# total time 23.504616498947144
# delay 0.03583073616027832
# total 74
# FPS: 3.1387901751363874
# total time 23.89507269859314
# delay -0.09813237190246582
# total 75
# FPS: 3.1298052906060483
# total time 24.283657789230347
# delay -0.13858509063720703
# total 76
# FPS: 3.1193322409601016
# total time 24.684770345687866
# delay -0.15111255645751953
# total 77
# FPS: 3.1336224848999916
# total time 24.89131999015808
# delay 0.043450355529785156
# total 78
# FPS: 3.1236789977711066
# total time 25.291484832763672
# delay -0.09060168266296387
# total 79
# FPS: 3.1198310913171654
# total time 25.642929792404175
# delay -0.10144495964050293
# total 80
# FPS: 3.1180231231159823
# total time 25.97799849510193
# delay -0.0850687026977539
# total 81
# FPS: 3.13599198780153
# total time 26.14802598953247
# delay 0.07997250556945801
# total 82
# FPS: 3.1240177702413967
# total time 26.568350791931152
# delay -0.07568645477294922
# total 83
# FPS: 3.117465723776611
# total time 26.945684909820557
# delay -0.1273341178894043
# total 84
# FPS: 3.1138401521044643
# total time 27.298206090927124
# delay -0.10252118110656738
# total 85
# FPS: 3.106014864140729
# total time 27.68875503540039
# delay -0.1405489444732666
# total 86
# FPS: 3.126443664245326
# total time 27.827144622802734
# delay 0.11161041259765625
# total 87
# FPS: 3.138696490603169
# total time 28.037116765975952
# delay 0.1551039218902588
# total 88
# FPS: 3.1470547929967023
# total time 28.280410051345825
# delay 0.17525982856750488
# total 89
# FPS: 3.1535323882338377
# total time 28.539424657821655
# delay 0.18046998977661133
# total 90
# FPS: 3.159335065176894
# total time 28.803529262542725
# delay 0.18064427375793457
# total 91
# FPS: 3.163413907882897
# total time 29.082504749298096
# delay 0.16580867767333984
# total 92
# FPS: 3.169746266648602
# total time 29.339887857437134
# delay 0.1737358570098877
# total 93
# FPS: 3.174980369200046
# total time 29.60648226737976
# delay 0.1716759204864502
# total 94
# FPS: 3.1784848374017285
# total time 29.88845467567444
# delay 0.15310072898864746
# total 95
# FPS: 3.187192099315239
# total time 30.120556592941284
# delay 0.18371343612670898
# total 96
# FPS: 3.1929984994030858
# total time 30.378968238830566
# delay 0.17635869979858398
# total 97
# FPS: 3.198345034843866
# total time 30.640846729278564
# delay 0.17869853973388672
# total 98
# FPS: 3.202895536114055
# total time 30.910542249679565
# delay 0.17356395721435547
# total 99
# FPS: 3.2071992167599235
# total time 31.179852962493896
# delay 0.1680138111114502
# total 100
# FPS: 3.2117444370197195
# total time 31.44808530807495
# delay 0.16383695602416992
# total 101
# FPS: 3.218312470610601
# total time 31.693628549575806
# delay 0.1690673828125
# total 102
# FPS: 3.2247907826555227
# total time 31.940056562423706
# delay 0.1855306625366211
# total 103
# FPS: 3.2285893179894383
# total time 32.21221089363098
# delay 0.17852044105529785
# total 104
# FPS: 3.232829027172213
# total time 32.47929263114929
# delay 0.17624616622924805
# total 105
# FPS: 3.2369168802338883
# total time 32.74721097946167
# delay 0.17522859573364258
# total 106
# FPS: 3.2410352376788754
# total time 33.014142751693726
# delay 0.17104816436767578
# total 107
# FPS: 3.243771140401969
# total time 33.294580698013306
# delay 0.1555178165435791
# total 108
# FPS: 3.243081896946157
# total time 33.610005378723145
# delay 0.10500168800354004
# total 109
# FPS: 3.2435523444929064
# total time 33.91343450546265
# delay 0.06538891792297363
# total 110
# FPS: 3.2437929682111974
# total time 34.219199895858765
# delay 0.024725675582885742
# total 111
# FPS: 3.24373505818414
# total time 34.52873730659485
# delay -0.021375417709350586
# total 112
# FPS: 3.2589458480475857
# total time 34.67386245727539
# delay 0.10487484931945801
# total 113
# FPS: 3.2613144111014485
# total time 34.95577073097229
# delay 0.0797569751739502
# total 114
# FPS: 3.2662213259794517
# total time 35.20888161659241
# delay 0.08902883529663086
# total 115
# FPS: 3.2779361289534235
# total time 35.388120889663696
# delay 0.17294692993164062
# total 116
# FPS: 3.28290863014497
# total time 35.63912773132324
# delay 0.18366074562072754
# total 117
# FPS: 3.2845592929111733
# total time 35.92567205429077
# delay 0.16291117668151855
# total 118
# FPS: 3.288270585331024
# total time 36.18923592567444
# delay 0.16354870796203613
# total 119

# %%
1002//5
