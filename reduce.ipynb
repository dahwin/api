# %%
import os
from PIL import Image

# Open the image file
img = Image.open(r"C:\Users\ALL USER\Desktop\text.png")

# Get the size of the image in pixels
width, height = img.size

# Get the file size in bytes
file_size_bytes = os.path.getsize(r"C:\Users\ALL USER\Desktop\text.png")

# Convert bytes to megabytes
file_size_mb = file_size_bytes / (1024 * 1024)

print(f"Image size: {width}x{height} pixels")
print(f"File size: {file_size_mb:.2f} MB")

# %%
import time
time.sleep(10)

from PIL import ImageGrab
import io

# Capture the screen
img = ImageGrab.grab()

# Create a BytesIO object to temporarily store the image data
image_bytes = io.BytesIO()
img.save(image_bytes, format='PNG')  # Save the image to the BytesIO object in PNG format

# Get the size of the image in bytes
image_size_bytes = image_bytes.tell()

# Convert bytes to megabytes
image_size_mb = image_size_bytes / (1024 * 1024)

print("Size of the captured image:", round(image_size_mb, 2), "MB")
img

# %%
import time
time.sleep(5)

from PIL import ImageGrab
import io

# Capture the screen
img = ImageGrab.grab()
img

# %%
#perfect

import cv2
import time
import threading
from PIL import Image
import asyncio
import nest_asyncio

nest_asyncio.apply()
time.sleep(5)

# url =  "http://localhost:3000/video_feed"
url =  "http://127.0.0.1:8000/video_feed"
# url =  "https://video.queendahyun.com/video_feed"
# url =  "https://name.queendahyun.com/video_feed"
# Initialize VideoCapture object
cap = cv2.VideoCapture(url)

# Get the default frame size
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output0.avi', fourcc, 3.8, (frame_width, frame_height))

async def read_frames_async():
    start_time = time.time()
    frame_count = 0

    all_count = 0
    
    while frame_count < 100:
        ret, frame = cap.read()
        out.write(frame)


        frame_count += 1
        all_count +=1

    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Time taken to get frames:", elapsed_time, "seconds")
    print("Frame count:", frame_count)
    


# Start reading frames asynchronously
asyncio.run(read_frames_async())

# Release everything when done
cap.release()

# %%
# %%writefile client.py
#perfect

import cv2
import time
import threading
from PIL import Image
import asyncio
import nest_asyncio

nest_asyncio.apply()
time.sleep(1)

# url =  "http://localhost:3000/video_feed"
url =  "http://127.0.0.1:8000/video_feed"
# url =  "https://video.queendahyun.com/video_feed"
# url =  "https://name.queendahyun.com/video_feed"
# Initialize VideoCapture object
cap = cv2.VideoCapture(url)

# Get the default frame size
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output0.avi', fourcc, 3.8, (frame_width, frame_height))
import time
async def read_frames_async():
    start_time = time.time()
    frame_count = 0

    all_count = 0
    
    while frame_count < 100:
        ret, frame = cap.read()
        out.write(frame)


        frame_count += 1
        all_count +=1

    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Time taken to get frames:", elapsed_time, "seconds")
    print("Frame count:", frame_count)
    


# Start reading frames asynchronously
asyncio.run(read_frames_async())

# Release everything when done
cap.release()
# Out:
# Time taken to get frames: 25.557615756988525 seconds
# Frame count: 100
